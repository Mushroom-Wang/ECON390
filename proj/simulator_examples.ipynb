# %%
# %load_ext autoreload
# %autoreload 2

# %%
from simulator import Covid19Simulator

# %% [markdown]
# Each point represents one person. The lighter the color, the severer his illness is.

# %%
simulator = Covid19Simulator(stu_num=50, K=4, I=0.35, S=0.01, L=3, seed=2)
simulator.draw()

# %%
for i in range(20):
    simulator.simulate_one_day()
simulator.draw()

# %%
for i in range(10):
    simulator.simulate_one_day()
simulator.draw()

# %%
log = simulator.get_log()
log
# Out:
#     infected number today  tested number today  tested positive rate today  \
# 0                       0                    0                    0.000000
# 1                       0                    0                    0.000000
# 2                       0                    1                    0.000000
# 3                       0                    1                    0.000000
# 4                       0                    0                    0.000000
# 5                       0                    1                    0.000000
# 6                       0                    0                    0.000000
# 7                       0                    0                    0.000000
# 8                       0                    2                    0.000000
# 9                       0                    0                    0.000000
# 10                      0                    1                    0.000000
# ...

# %%
simulator.stu_list
# Out:
# [0(infected)(tested),
#  1(infected)(tested),
#  2(infected)(tested),
#  3(infected)(tested),
#  4(infected)(tested),
#  5(infected)(tested),
#  6(infected)(tested),
#  7(infected),
#  8(infected)(tested),
#  9(infected)(tested),
#  10(infected)(tested),
#  11(infected),
#  12,
#  13(infected)(tested),
#  14(infected)(tested),
#  15(infected)(tested),
#  16,
#  17,
#  18(infected),
#  19(infected),
#  20(infected),
#  21(infected)(tested),
#  22,
#  23(infected),
#  24,
#  25(infected)(tested),
#  26,
#  27(infected)(tested),
#  28(infected)(tested),
#  29,
#  30(infected),
#  31,
#  32(infected),
#  33,
#  34,
#  35,
#  36(infected)(tested),
#  37(infected)(tested),
#  38(infected)(tested),
#  39(infected)(tested),
#  40(infected)(tested),
#  41,
#  42,
#  43,
#  44,
#  45(infected)(tested),
#  46,
#  47(infected)(tested),
#  48(infected),
#  49(infected)(tested)]
